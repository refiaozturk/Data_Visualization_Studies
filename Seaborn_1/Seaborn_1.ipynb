# %% [markdown]
# # Importing Libraries

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Reading The Data

# %%
# You can run this 2 codes with deleting the "#" signs. If it doesn't work, you should add encoding= "windows-1252" argument in pd.read_csv function.

# df = pd.read_csv("PoliceKillingsUS.csv")
# df.head()

# %%
df = pd.read_csv("PoliceKillingsUS.csv", encoding= "windows-1252")
df.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# 2  Not fleeing        False
# 3  Not fleeing        False
# 4  Not fleeing        False

# %%
# Let's look at some information about the data!

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2535 entries, 0 to 2534
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       2535 non-null   int64
#  1   name                     2535 non-null   object
#  2   date                     2535 non-null   object
#  3   manner_of_death          2535 non-null   object
#  4   armed                    2526 non-null   object
#  5   age                      2458 non-null   float64
#  6   gender                   2535 non-null   object
#  7   race                     2340 non-null   object
#  8   city                     2535 non-null   object
#  9   state                    2535 non-null   object
#  10  signs_of_mental_illness  2535 non-null   bool
#  11  threat_level             2535 non-null   object
#  12  flee                     2470 non-null   object
#  13  body_camera              2535 non-null   bool
# dtypes: bool(2), float64(1), int64(1), object(10)
# memory usage: 242.7+ KB

# %%
# Finding the shape of data
# The shape of data gives us the total number of indexes and columns in data.
# Output --> (total_number_of_indexes , total_number_of_columns)

df.shape
# Out:
# (2535, 14)

# %% [markdown]
# # Creating Graphs

# %% [markdown]
# ## Box Plot of Age in both genders separated by manner of death.

# %%
# Finding the unique values in manner_of_death column.

df.manner_of_death.unique()
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %% [markdown]
# **Note: Demonstrate the Quartiles of age in both genders separated by manner of death.**

# %%
df.dropna(inplace=True)

# %%
plt.figure(figsize = (5, 4))

sns.boxplot(data = df, x = "gender", y = "age", hue = "manner_of_death")

plt.show()

# %% [markdown]
# ## Swarm Plot

# %% [markdown]
# **Note: Demonstrate the age in both genders separated by manner of death by a swarm plot.**

# %%
plt.figure(figsize = (5, 4))

sns.swarmplot(df, x = "gender", y = "age", hue = "manner_of_death")

plt.show()

# %%
plt.figure(figsize = (5, 4))

sns.swarmplot(df, x = "gender", y = "age", hue = "manner_of_death")

# You can arrange the location of legend by using "loc" argument. 
plt.legend(loc = "upper right")

plt.show()

# %%
plt.figure(figsize = (5, 4))

sns.swarmplot(df, x = "gender", y = "age", hue = "manner_of_death")

# You can also arrange the location of legend by using "bbox_to_anchor" argument. 
plt.legend(bbox_to_anchor=(1.02, 1.2))

plt.show()

# %% [markdown]
# ## Plotting 12 Most Dangerous Cities

# %%
# Finding the 12 most dangerous cities by using the "groupby" function.

most_dangerous_cities = df.groupby("city")["city"].count().sort_values(ascending= False).head(12)
most_dangerous_cities
# Out:
# city
# Los Angeles      35
# Phoenix          28
# Houston          24
# Chicago          22
# Austin           18
# Las Vegas        17
# Columbus         16
# San Antonio      15
# Miami            15
# St. Louis        14
# Indianapolis     14
# Oklahoma City    13
# Name: city, dtype: int64

# %%
# defining the city names

city_names = most_dangerous_cities.index
city_names
# Out:
# Index(['Los Angeles', 'Phoenix', 'Houston', 'Chicago', 'Austin', 'Las Vegas',
#        'Columbus', 'San Antonio', 'Miami', 'St. Louis', 'Indianapolis',
#        'Oklahoma City'],
#       dtype='object', name='city')

# %%
# defining the city values (counts)

city_values = most_dangerous_cities.values
city_values
# Out:
# array([35, 28, 24, 22, 18, 17, 16, 15, 15, 14, 14, 13], dtype=int64)

# %%
# Plotting with seaborn barplot

fig, ax = plt.subplots(figsize = (9, 5))

ax = sns.barplot(x = city_names, y = city_values, legend= True, palette= "husl")
ax.set_title("Most Dangerous Cities", color = "red", size = 15)

plt.xticks(rotation = 45, color = "blue", size = 8)

plt.show()

# %%
# Plotting with seaborn countplot

fig, ax = plt.subplots(figsize = (6, 4))

ax = sns.countplot(data = df, x = "city", order = most_dangerous_cities.index, legend= True, palette= "tab10")
ax.set_title("Most Dangerous Cities", color = "blue", size = 10)

plt.xticks(rotation = 45, color = "black", size = 8)
plt.yticks(size = 7)

plt.show()

# %% [markdown]
# ## Plotting 20 Most Dangerous States

# %%
# Finding the 20 most dangerous states by using "value_counts".

df["state"].value_counts(ascending = False).head(20)
# Out:
# state
# CA    366
# TX    200
# FL    136
# AZ    105
# OH     70
# NC     66
# OK     65
# CO     63
# GA     61
# MO     58
# TN     56
# IL     56
# WA     51
# LA     47
# AL     45
# PA     45
# NY     43
# VA     43
# WI     42
# NM     41
# Name: count, dtype: int64

# %%
# defining the state names

state_names = df["state"].value_counts(ascending = False).head(20).index
state_names
# Out:
# Index(['CA', 'TX', 'FL', 'AZ', 'OH', 'NC', 'OK', 'CO', 'GA', 'MO', 'TN', 'IL',
#        'WA', 'LA', 'AL', 'PA', 'NY', 'VA', 'WI', 'NM'],
#       dtype='object', name='state')

# %%
# defining the state values

state_values = df["state"].value_counts(ascending = False).head(20).values
state_values
# Out:
# array([366, 200, 136, 105,  70,  66,  65,  63,  61,  58,  56,  56,  51,
#         47,  45,  45,  43,  43,  42,  41], dtype=int64)

# %%
# Plotting with seaborn barplot

fig, ax = plt.subplots(figsize = (6, 4))

ax = sns.barplot(x = state_names, y = state_values, legend= True, palette= "husl")
ax.set_title("Most Dangerous States", color = "blue", size = 10)

plt.xticks(rotation = 45, color = "black", size = 8)
plt.xlabel(xlabel= "")

plt.show()

# %%
# Plotting with seaborn countplot

fig, ax = plt.subplots(figsize = (6, 4))

ax = sns.countplot(data = df, x = "state", order = state_names, legend= True, palette= "bright")
ax.set_title("Most Dangerous States", color = "blue", size = 10)

plt.xticks(rotation = 45, color = "black", size = 8)
plt.yticks(size = 7)
plt.xlabel(xlabel= "state", size = 7.5)
plt.ylabel(ylabel= "count", size = 7.5)

plt.show()

# %% [markdown]
# ## Plotting Having Mental Illness or Not for killed people

# %%
df[(df["signs_of_mental_illness"] == True) | (df["signs_of_mental_illness"] == False)].head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# 2  Not fleeing        False
# 3  Not fleeing        False
# 4  Not fleeing        False

# %%
# Finding the number of having mental illness or not for killed people

df["signs_of_mental_illness"].value_counts()
# Out:
# signs_of_mental_illness
# False    1681
# True      573
# Name: count, dtype: int64

# %%
# Plotting with seaborn barplot

plt.figure(figsize = (4.5, 3))

sns.barplot(data = df, y = "signs_of_mental_illness")
plt.yticks(size = 7)
plt.ylabel(ylabel= "signs_of_mental_illness", size = 7.5)

plt.show()

# %%
# Plotting with seaborn countplot

plt.figure(figsize = (4.5, 3))

sns.countplot(data = df, x = "signs_of_mental_illness", palette = "tab10")

plt.xticks(size = 7)
plt.yticks(np.arange(0, 1650, 200), size = 7)

plt.xlabel(xlabel = "signs_of_mental_illness", size = 7.5)
plt.ylabel(ylabel= "count", size = 7.5)

plt.show()

# %% [markdown]
# ## Plotting Number of Threat Types

# %%
df["threat_level"].value_counts()
# Out:
# threat_level
# attack          1462
# other            677
# undetermined     115
# Name: count, dtype: int64

# %%
# Plotting with seaborn barplot

plt.figure(figsize = (4.5, 3))

sns.countplot(data = df, x = "threat_level", palette = "tab10")

plt.xticks(size = 7)
plt.yticks(np.arange(0, 1450, 200), size = 7)

plt.xlabel(xlabel = "threat_level", size = 7.6)
plt.ylabel(ylabel= "count", size = 7.5)

plt.show()

# %% [markdown]
# ## Plotting Number of Flee Types

# %%
df["flee"].value_counts()
# Out:
# flee
# Not fleeing    1528
# Car             360
# Foot            278
# Other            88
# Name: count, dtype: int64

# %%
# Plotting with seaborn countplot

plt.figure(figsize = (4.5, 3))

sns.countplot(data = df, x = "flee", palette = "tab10")

plt.xticks(size = 7)
plt.yticks(np.arange(0, 1650, 200), size = 7)

plt.xlabel(xlabel = "flee", size = 7.6)
plt.ylabel(ylabel= "count", size = 7.5)

plt.show()
